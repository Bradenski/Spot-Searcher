# %%
from IPython.display import display

# %%
import pandas as pd
# import cv2
from PIL import Image, ImageDraw
import matplotlib.pyplot as plt

# %%
spot_data = pd.read_csv("spot_dataset/spot_labels.csv")
spot_data
# Out:
#                                  image_name        lat        lon  \
# 0          ./spot_dataset/zuccotti_park.png  40.709360 -74.011790
# 1    ./spot_dataset/three_up_three_down.png  40.725248 -74.011773
# 2        ./spot_dataset/columbus_circle.png  40.768116 -73.981823
# 3              ./spot_dataset/c_benches.png  40.705475 -74.005988
# 4         ./spot_dataset/pyramid_ledges.png  40.704747 -74.008049
# 5  ./spot_dataset/water_street_ledges_2.png  40.704546 -74.006341
# 6  ./spot_dataset/water_street_ledges_2.png  40.704546 -74.006341
# 7   ./spot_dataset/pine_street_ledges_2.png  40.705347 -74.006569
# 8   ./spot_dataset/pine_street_ledges_1.png  40.705347 -74.006569
#
#   known_features             spot_name
# 0   stairs ledge         zuccotti_park
# 1         stairs   three_up_three_down
# 2          ledge       columbus_circle
# 3          bench             c_benches
# 4   stairs ledge        pyramid_ledges
# 5          bench  water_street_benches
# 6          bench  water_street_benches
# 7          bench    pine_street_ledges
# 8          bench    pine_street_ledges

# %%
import moondream as md
# Initialize the model to run locally
model = md.vl(endpoint="http://localhost:2020/v1")

# %%
# image = cv2.imread(spot_data.iloc[7]['image_name'])
image = Image.open(spot_data.iloc[7]['image_name'])
caption = model.caption(image)['caption']
answer = model.query(image, "Are there stairs, ledges, or benches in the image?")['answer']
detection = model.detect(image, 'bench')['objects']
points = model.point(image, 'car')['points']
overlay = image.copy()
draw = ImageDraw.Draw(overlay)
w, h = overlay.size
for box in detection:
    draw.rectangle([
        int(box['x_min'] * w),
        int(box['y_min'] * h),
        int(box['x_max'] * w),
        int(box['y_max'] * h)
    ], outline='red', width=3)

display(overlay)
# Out:
# <PIL.Image.Image image mode=RGBA size=1865x1286>

# %%
def process_image(image_path): 
    """
    Return VLM prediction of skate spot features in the image and return hits for keywords
    Our list of keywords: BENCH, STAIRS, LEDGE
    """
    image = Image.open(image_path)

# %%
def batch_process_spots(df):
    results = []
    for idx, row in df.iterrows():
        print(f"Processing {row['spot_name']}...")
        detected = process_spot_image(row['image_name'])
        results.append({
            'spot_name': row['spot_name'],
            'known_features': row['known_features'].split(),
            'detected_features': detected,
            'lat': row['lat'],
            'lon': row['lon']
        })
    return results
